# %% [markdown]
# # Eigenvectors and Eigenvalues

# %%
pd.read_html('https://learn.corporatefinanceinstitute.com/my-courses/collections?pageNumber=1&pageSize=25&sort=name_asc')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 pd.read_html('https://learn.corporatefinanceinstitute.com/my-courses/collections?pageNumber=1&pageSize=25&sort=name_asc')
#
# File C:\ProgramData\Anaconda3\envs\Jupyter\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...
